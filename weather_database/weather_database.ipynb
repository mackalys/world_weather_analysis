# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import time
from datetime import datetime
import requests
import json
from weather_database_config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(80.13439776341102, 55.51806930459978), (18.195852081796488, 98.74224267117057), (77.4029195720878, 9.684361391453535), (-29.55584943246746, 93.5676753982865), (-49.61858315484935, -13.028781576152937), (-58.97780018273663, -22.885178091842192), (63.25652615159322, -157.82995114997797), (-13.536214850383772, -13.372084531114865), (40.416794523798245, 173.85536113543816), (-25.502493075060386, 164.83237930421274), (76.9770001747626, -21.480732624810088), (8.998064415699474, 166.86686547203203), (-46.09003452505772, 178.70497193729), (24.99526220803068, -40.9946777415953), (50.52637057088813, -64.54275418096505), (26.249778359800516, -160.4930898715254), (56.26674106048597, 110.25995037938037), (63.825997520526556, 14.412211511518223), (15.405345669558557, 14.399641393537735), (55.292165679708006, -119.13327138334101), (31.070715404380422, -57.672980125469394), (85.532246454433, -157.3421157092415), (-34.31822138982272, -166.94636089797612), (-36.98364092710019, -40.66756322184543), (-42.97544771082218, -71.46053904103685), (-54.15597934268939, 26.42346820108375), (-61.34950514254634, 50.38761213268023), (-29.364495084918047, 106.20020569974974), (12.299690919907789, -17.532432402333285), (-25.897620454504093, -155.69152644686872), (67.97162477852052, -43.37317253921333), (-2.4501481914177248, 19.094231412196024), (-35.556241839026626, 63.61646137748184), (-49.24676039864779, -17.850550817952353), (66.17292842805259, -178.55297176000317), (63.99849698357497, 17.959659533321997), (40.43030832381251, 104.47795766841551), (60.69947996767797, 126.60070066521621), (-2.874020113320327, -8.747419872042371), (-37.324083318471935, 123.03522807348429), (-83.43595617306782, 33.01308643506462), (74.99062990613925, 17.06216632192678), (46.86954893304781, 23.105933382962093), (-59.60303200862066, -51.171051715989904), (-87.78114021883627, -59.84828537993391), (-51.75343937255829, -11.503399572106815), (-1.5116029883175486, -111.40214192602265), (34.689949665728406, 101.57364800470208), (-77.49989417572783, 65.11378152137286), (61.710988111810536, 17.481460537764463), (-39.90060125978029, 28.38186024138136), (-80.98196312205025, 156.08232924682), (84.01744511930903, -99.31856474560158), (-49.96560275021705, 125.18181523727719), (-67.98146139214913, -71.71019396199223), (58.22233196704485, 162.6589562855865), (3.482318309427484, -176.9394456611421), (-35.71194081866815, 93.24748232140524), (65.00545540160596, -34.97973844679629), (64.30040186492224, -132.95179472614), (-1.51177377825762, -79.34010456067047), (-64.0374593860403, -52.392753530217604), (-38.44610436086692, -59.79155914296399), (69.81510258899294, 32.48602097285189), (-67.74650266994257, 143.37975188887265), (34.362710852416924, -62.31803639505695), (-4.239801496742473, 46.85984732205068), (-24.62415160566691, 115.81420296268578), (-85.0098640893059, -150.08226708154044), (-79.09340096190779, -163.7072714643166), (-74.19545664256367, -168.42323604615396), (-17.279921897843877, 85.71782292553888), (-11.942838853497278, 174.78024829003584), (23.019672874689675, -33.94401751653439), (55.070203596555785, -88.37578158126745), (-68.83566356353538, 39.7140928160955), (-41.79667786948246, -41.542182736852766), (34.58553750351767, -108.61444267906424), (-72.5934480417494, 39.429180233797524), (-74.359308516307, -135.06120569450133), (82.3276340562071, 9.234455089765447), (-28.45831209337956, 104.67368006607552), (78.91163268058423, 59.728520176889134), (10.517491453410187, -135.20996901670597), (5.227941281694385, 45.20140232124771), (-43.71551197379737, -87.87134707829702), (85.45984846569118, 112.13818231431372), (-50.95734090822159, -110.11567075035494), (-40.20848327662218, -146.8140826586828), (25.23962775418228, -140.01854330382332), (-33.93171319035156, 4.15070368229641), (16.21116759373612, -59.532269568893), (64.1453569567071, -95.29179854985517), (89.34891502519241, 34.37905405848409), (59.95653950466462, -16.403886443427893), (2.3031352028006182, -99.06800704080719), (25.0287085 ...

# %%
# Get the nearest city using the citipy module.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 734

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9374d2f8b06fa81d86401535fae1e760

# %%
# Retrieve the following information from the API call:
    # Latitude and longitude
    # Maximum temperature
    # Percent humidity
    # Percent cloudiness
    # Wind speed
    # Weather description (for example, clouds, fog, light rain, clear sky)
    
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | pa sang
# Processing Record 3 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | chuy
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | noumea
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | waipawa
# Processing Record 14 of Set 1 | ponta do sol
# Processing Record 15 of Set 1 | havre-saint-pierre
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | kichera
# Processing Record 18 of Set 1 | ostersund
# Processing Record 19 of Set 1 | mao
# Processing Record 20 of Set 1 | wembley
# Processing Record 21 of Set 1 | saint george
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | san carlos de bariloche
# Processing Record 26 of Set 1 | kruisfontein
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | geraldton
# Processing Record 29 of Set 1 | oussouye
# Processing Record 30 of Set 1 | avera
# Processing Record 31 of Set 1 | tasiilaq
# Processing Record 32 of Set 1 | inongo
# Processing Record 33 of Set 1 | souillac
# Processing Record 34 of Set 1 | egvekinot
# Processing Record 35 of Set 1 | ornskoldsvik
# Processing Record 36 of Set 1 | shitanjing
# Processing Record 37 of Set 1 | berdigestyakh
# Processing Record 38 of Set 1 | harper
# Processing Record 39 of Set 1 | esperance
# Processing Record 40 of Set 1 | port elizabeth
# Processing Record 41 of Set 1 | longyearbyen
# Processing Record 42 of Set 1 | izvoru crisului
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | linxia
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | hudiksvall
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | ossora
# Processing Record 3 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | mayo
# Processing Record 6 of Set 2 | ventanas
# Processing Record 7 of Set 2 | tres arroyos
# Processing Record 8 of Set 2 | snezhnogorsk
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | kismayo
# Processing Record 11 of Set 2 | mataura
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | asau
# Processing Record 15 of Set 2 | rio grande
# Processing Record 16 of Set 2 | grants
# Processing Record 17 of Set 2 | rikitea
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | xuddur
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | luderitz
# Processing Record 25 of Set 2 | saint-francois
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | berlevag
# Processing Record 28 of Set 2 | hofn
# Processing Record 29 of Set 2 | umm lajj
# Processing Record 30 of Set 2 | codrington
# Processing Record 31 of Set 2 | vilhena
# Processing Record 32 of Set 2 | punta arenas
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | dikson
# Processing Record 35 of Set 2 | ojinaga
# Processing Record 36 of Set 2 | airai
# Processing Record 37 of Set 2 | husavik
# Processing Record 38 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 2 | scarborough
# Processing Record 40 of Set 2 | camargo
# Processing Record 41 of Set 2 | touros
# Processing Record 42 of Set 2 | maymyo
# Processing Record 43 of Set 2 | hajdunanas
# Processing Record 44 of Set 2 | bozoum
# Processing Record 45 of Set 2 | mar del plata
# Processing Record 46 of Set 2 | altamira
# Processing Record 47 of Set 2 | bengkulu
# Processing Record 48 of Set 2 | izumo
# Processing Record 49 of Set 2 | lichinga
# Processing Record 50 of Set 2 | lebu
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | half moon bay
# Processing Record 4 of Set 3 | buenos aires
# Processing Record 5 of Set 3 | iqaluit
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | watsa
# Processing Record 8 of Set 3 | cherskiy
# Processing Record 9 of Set 3 | chokurdakh
# Processing Record 10 of Set 3 | saint-georges
# Processing Record 11 of Set 3 | hovd
# Processing Record 12 of Set 3 | ryotsu
# Processing Record 13 of Set 3 | wau
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | faanui
# Processing Record 16 of Set 3 | aswan
# Processing Record 17 of Set 3 | palamos
# Processing Record 18 of Set 3 | shingu
# Processing Record 19 of Set 3 | khatanga
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | seymchan
# Processing Record 22 of Set 3 | kharp
# Processing Record 23 of Set 3 | belmonte
# Processing Record 24 of Set 3 | bredasdorp
# Processing Record 25 of Set 3 | cayenne
# Processing Record 26 of Set 3 | manicore
# Processing Record 27 of Set 3 | kamina
# Processing Record 28 of Set 3 | ambatofinandrahana
# Processing Record 29 of Set 3 | serenje
# Processing Record 30 of Set 3 | norman wells
# Processing Record 31 of Set 3 | haines junction
# Processing Record 32 of Set 3 | portage
# Processing Record 33 of Set 3 | isangel
# Processing Record 34 of Set 3 | albany
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | kulu
# Processing Record 37 of Set 3 | ternate
# Processing Record 38 of Set 3 | ocos
# Processing Record 39 of Set 3 | tongren
# Processing Record 40 of Set 3 | bajo baudo
# City not found. Skipping...
# Processing Record 41 of Set 3 | kalabo
# Processing Record 42 of Set 3 | pitimbu
# Processing Record 43 of Set 3 | san rafael
# Processing Record 44 of Set 3 | zhigansk
# Processing Record 45 of Set 3 | camaqua
# Processing Record 46 of Set 3 | mount gambier
# Processing Record 47 of Set 3 | launceston
# Processing Record 48 of Set 3 | lockport
# Processing Record 49 of Set 3 | charallave
# Processing Record 50 of Set 3 | sorong
# Processing Record 1 of Set 4 | poum
# Processing Record 2 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 4 | asfi
# Processing Record 4 of Set 4 | qaqortoq
# Processing Record 5 of Set 4 | sitka
# Processing Record 6 of Set 4 | shubarshi
# Processing Record 7 of Set 4 | rio verde de mato grosso
# Processing Record 8 of Set 4 | ayr
# Processing Record 9 of Set 4 | marawi
# Processing Record 10 of Set 4 | kaitangata
# Processing Record 11 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 4 | atbasar
# Processing Record 13 of Set 4 | loughborough
# Processing Record 14 of Set 4 | severo-kurilsk
# Processing Record 15 of Set 4 | kahului
# Processing Record 16 of Set 4 | ribeira grande
# Processing Record 17 of Set 4 | tuatapere
# Processing Record 18 of Set 4 | wamba
# Processing Record 19 of Set 4 | hami
# Processing Record 20 of Set 4 | skibbereen
# Processing Record 21 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 4 | presidencia roque saenz pena
# Processing Record 23 of Set 4 | broken hill
# Processing Record 24 of Set 4 | santa maria
# Processing Record 25 of Set 4 | minas
# Processing Record 26 of Set 4 | nelson bay
# Processing Record 27 of Set 4 | abiy adi
# City not found. Skipping...
# Processing Record 28 of Set 4 | tamandare
# Processing Record 29 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 4 | sur
# Processing Record 31 of Set 4 | ciudad bolivar
# Processing Record 32 of Set 4 | monrovia
# Processing Record 33 of Set 4 | paamiut
# Processing Record 34 of Set 4 | hudson bay
# Processing Record 35 of Set 4 | asyut
# Processing Record 36 of Set 4 | ahipara
# Processing Record 37 of Set 4 | yulara
# Processing Record 38 of Set 4 | labuan
# Processing Record 39 of Set 4 | west plains
# Processing Record 40 of Set 4 | caravelas
# Processing Record 41 of Set 4 | andra
# Processing Record 42 of Set 4 | tautira
# Processing Record 43 of Set 4 | lavrentiya
# Processing Record 44 of Set 4 | sept-iles
# Processing Record 45 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 4 | sao joao da barra
# Processing Record 47 of Set 4 | maniitsoq
# Processing Record 48 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 4 | jiexiu
# Processing Record 1 of Set 5 | altay
# Processing Record 2 of Set 5 | pisco
# Processing Record 3 of Set 5 | kem
# Processing Record 4 of Set 5 | mnogovershinnyy
# Processing Record 5 of Set 5 | vanimo
# Processing Record 6 of Set 5 | victoria
# Processing Record 7 of Set 5 | tuy hoa
# Processing Record 8 of Set 5 | vostok
# Processing Record 9 of Set 5 | wana
# Processing Record 10 of Set 5 | port hardy
# Processing Record 11 of Set 5 | mahajanga
# Processing Record 12 of Set 5 | cabo san lucas
# Processing Record 13 of Set 5 | houma
# Processing Record 14 of Set 5 | araouane
# Processing Record 15 of Set 5 | okhotsk
# Processing Record 16 of Set 5 | oriximina
# Processing Record 17 of Set 5 | luanda
# Processing Record 18 of Set 5 | tomatlan
# Processing Record 19 of Set 5 | deputatskiy
# Processing Record 20 of Set 5 | bilma
# Processing Record 21 of Set 5 | klaksvik
# Processing Record 22 of Set 5 | osuna
# Processing Record 23 of Set 5 | daru
# Processing Record 24 of Set 5 | sioux lookout
# Processing Record 25 of Set 5 | oberstdorf
# Processing Record 26 of Set 5 | westport
# Processing Record 27 of Set 5 | boshnyakovo
# Processing Record 28 of Set 5 | lagoa
# Processing Record 29 of Set 5 | el dorado
# Processing Record 30 of Set 5 | ancud
# Processing Record 31 of Set 5 | salalah
# Processing Record 32 of Set 5 | maumere
# Processing Record 33 of Set 5 | pafos
# Processing Record 34 of Set 5 | omboue
# Processing Record 35 of Set 5 | nalut
# Processing Record 36 of Set 5 | porbandar
# Processing Record 37 of Set 5 | yining
# Processing Record 38 of Set 5 | olafsvik
# Processing Record 39 of Set 5 | dangara
# Processing Record 40 of Set 5 | huarmey
# Processing Record 41 of Set 5 | saint-philippe
# Processing Record 42 of Set 5 | bende
# Processing Record 43 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 5 | bandarbeyla
# Processing Record 45 of Set 5 | torbay
# Processing Record 46 of Set 5 | bousso
# Processing Record 47 of Set 5 | bonga
# Processing Record 48 of Set 5 | shestakovo
# Processing Record 49 of Set 5 | mount isa
# Processing Record 50 of Set 5 | tateyama
# Processing Record 1 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 2 of Set 6 | preobrazheniye
# Processing Record 3 of Set 6 | padang
# Processing Record 4 of Set 6 | raudeberg
# Processing Record 5 of Set 6 | coruripe
# Processing Record 6 of Set 6 | dabat
# Processing Record 7 of Set 6 | maragogi
# Processing Record 8 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 6 | ust-nera
# Processing Record 10 of Set 6 | alice springs
# Processing Record 11 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 6 | qinzhou
# Processing Record 13 of Set 6 | hasaki
# Processing Record 14 of Set 6 | riohacha
# Processing Record 15 of Set 6 | san ignacio
# Processing Record 16 of Set 6 | upernavik
# Processing Record 17 of Set 6 | matay
# Processing Record 18 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 19 of Set 6 | sobolevo
# Processing Record 20 of Set 6 | matamoros
# Processing Record 21 of Set 6 | stromness
# Processing Record 22 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 23 of Set 6 | san patricio
# Processing Record 24 of Set 6 | waddan
# Processing Record 25 of Set 6 | gladstone
# Processing Record 26 of Set 6 | jumla
# Processing Record 27 of Set 6 | saldanha
# Processing Record 28 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | dibombari
# Processing Record 30 of Set 6 | nazas
# Processing Record 31 of Set 6 | itaborai
# Processing Record 32 of Set 6 | constitucion
# Processing Record 33 of Set 6 | mahebourg
# Processing Record 34 of Set 6 | pokosnoye
# Processing Record 35 of Set 6 | arona
# Processing Record 36 of Set 6 | ginir
# Processing Record 37 of Set 6 | villazon
# Processing Record 38 of Set 6 | lasa
# Processing Record 39 of Set 6 | san cristobal
# Processing Record 40 of Set 6 | sirmaur
# Processing Record 41 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 6 | hamilton
# Processing Record 43 of Set 6 | novovarshavka
# Processing Record 44 of Set 6 | baykit
# Processing Record 45 of Set 6 | namatanai
# Processing Record 46 of Set 6 | fortuna
# Processing Record 47 of Set 6 | te anau
# Processing Record 48 of Set 6 | salihli
# Processing Record 49 of Set 6 | manokwari
# Processing Record 50 of Set 6 | yerbogachen
# Processing Record 1 of Set 7 | prince rupert
# Processing Record 2 of Set 7 | carambei
# Processing Record 3 of Set 7 | lamu
# Processing Record 4 of Set 7 | kardymovo
# Processing Record 5 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 6 of Set 7 | luanshya
# Processing Record 7 of Set 7 | yuanping
# Processing Record 8 of Set 7 | tezu
# Processing Record 9 of Set 7 | schrobenhausen
# Processing Record 10 of Set 7 | ambulu
# Processing Record 11 of Set 7 | carbonia
# Processing Record 12 of Set 7 | dianopolis
# City not found. Skipping...
# Processing Record 13 of Set 7 | kalmunai
# Processing Record 14 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 7 | ewa beach
# Processing Record 16 of Set 7 | bonthe
# Processing Record 17 of Set 7 | leningradskiy
# Processing Record 18 of Set 7 | guerrero negro
# Processing Record 19 of Set 7 | purificacion
# Processing Record 20 of Set 7 | boa vista
# Processing Record 21 of Set 7 | kosa
# Processing Record 22 of Set 7 | hambantota
# Processing Record 23 of Set 7 | tiksi
# Processing Record 24 of Set 7 | coihaique
# Processing Record 25 of Set 7 | primorsko
# Processing Record 26 of Set 7 | erie
# Processing Record 27 of Set 7 | walvis bay
# Processing Record 28 of Set 7 | road town
# Processing Record 29 of Set 7 | ambon
# Processing Record 30 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 7 | humboldt
# Processing Record 32 of Set 7 | vestmannaeyjar
# Processing Record 33 of Set 7 | saravan
# Processing Record 34 of Set 7 | matara
# Processing Record 35 of Set 7 | araguatins
# City not found. Skipping...
# Processing Record 36 of Set 7 | la ronge
# Processing Record 37 of Set 7 | benguela
# Processing Record 38 of Set 7 | uruzgan
# Processing Record 39 of Set 7 | baoqing
# Processing Record 40 of Set 7 | erzin
# Processing Record 41 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 7 | bobonong
# City not found. Skipping...
# Processing Record 43 of Set 7 | manbij
# Processing Record 44 of Set 7 | homer
# Processing Record 45 of Set 7 | kimbe
# Processing Record 46 of Set 7 | kawalu
# Processing Record 47 of Set 7 | katsuura
# Processing Record 48 of Set 7 | talnakh
# Processing Record 49 of Set 7 | lorengau
# Processing Record 50 of Set 7 | sale
# Processing Record 1 of Set 8 | nagato
# Processing Record 2 of Set 8 | narsaq
# Processing Record 3 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 8 | pilar
# Processing Record 5 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 6 of Set 8 | kiruna
# Processing Record 7 of Set 8 | cabedelo
# Processing Record 8 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 8 | polyarnyy
# Processing Record 10 of Set 8 | acuna
# City not found. Skipping...
# Processing Record 11 of Set 8 | arkhangelsk
# Processing Record 12 of Set 8 | kedrovyy
# Processing Record 13 of Set 8 | piacabucu
# Processing Record 14 of Set 8 | platanos
# Processing Record 15 of Set 8 | kibaya
# Processing Record 16 of Set 8 | grand-lahou
# Processing Record 17 of Set 8 | marietta
# Processing Record 18 of Set 8 | fort nelson
# Processing Record 19 of Set 8 | alofi
# Processing Record 20 of Set 8 | kodiak
# Processing Record 21 of Set 8 | ransang
# Processing Record 22 of Set 8 | saint-augustin
# Processing Record 23 of Set 8 | segou
# Processing Record 24 of Set 8 | buala
# Processing Record 25 of Set 8 | kang
# Processing Record 26 of Set 8 | dicabisagan
# Processing Record 27 of Set 8 | juneau
# Processing Record 28 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 29 of Set 8 | sydney
# Processing Record 30 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 8 | ngama
# Processing Record 32 of Set 8 | port shepstone
# Processing Record 33 of Set 8 | verkhnyaya toyma
# Processing Record 34 of Set 8 | ngunguru
# Processing Record 35 of Set 8 | port lincoln
# Processing Record 36 of Set 8 | neiba
# Processing Record 37 of Set 8 | north myrtle beach
# Processing Record 38 of Set 8 | murray bridge
# Processing Record 39 of Set 8 | urusha
# Processing Record 40 of Set 8 | christchurch
# Processing Record 41 of Set 8 | agropoli
# Processing Record 42 of Set 8 | kosovska mitrovica
# Processing Record 43 of Set 8 | pierre
# Processing Record 44 of Set 8 | vila franca do campo
# Processing Record 45 of Set 8 | yar-sale
# Processing Record 46 of Set 8 | karlovac
# Processing Record 47 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 48 of Set 8 | paralimni
# Processing Record 49 of Set 8 | oranjemund
# Processing Record 50 of Set 8 | visnes
# Processing Record 1 of Set 9 | malakal
# Processing Record 2 of Set 9 | bosaso
# Processing Record 3 of Set 9 | kollumerland
# City not found. Skipping...
# Processing Record 4 of Set 9 | port blair
# Processing Record 5 of Set 9 | ponta delgada
# Processing Record 6 of Set 9 | nishihara
# Processing Record 7 of Set 9 | caldwell
# Processing Record 8 of Set 9 | qandahar
# City not found. Skipping...
# Processing Record 9 of Set 9 | ballina
# Processing Record 10 of Set 9 | oudtshoorn
# Processing Record 11 of Set 9 | trinidad
# Processing Record 12 of Set 9 | esna
# Processing Record 13 of Set 9 | lerwick
# Processing Record 14 of Set 9 | le vauclin
# Processing Record 15 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 9 | mbaiki
# Processing Record 17 of Set 9 | nipawin
# Processing Record 18 of Set 9 | mbarara
# Processing Record 19 of Set 9 | kharitonovo
# Processing Record 20 of Set 9 | pasighat
# Processing Record 21 of Set 9 | viedma
# Processing Record 22 of Set 9 | sao filipe
# Processing Record 23 of Set 9 | dunedin
# Processing Record 24 of Set 9 | saint-pierre
# Processing Record 25 of Set 9 | verkhnevilyuysk
# Processing Record 26 of Set 9 | rawson
# Processing Record 27 of Set 9 | vardo
# Processing Record 28 of Set 9 | flin flon
# Processing Record 29 of Set 9 | praya
# Processing Record 30 of Set 9 | salto
# Processing Record 31 of Set 9 | valle hermoso
# Processing Record 32 of Set 9 | shebunino
# Processing Record 33 of Set 9 | sembe
# Processing Record 34 of Set 9 | mana
# Processing Record 35 of Set 9 | billings
# Processing Record 36 of Set 9 | college
# Processing Record 37 of Set 9 | clyde river
# Processing Record 38 of Set 9 | naze
# Processing Record 39 of Set 9 | whitehorse
# Processing Record 40 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 41 of Set 9 | skjervoy
# Processing Record 42 of Set 9 | dingle
# Processing Record 43 of Set 9 | san quintin
# Processing Record 44 of Set 9 | meulaboh
# Processing Record 45 of Set 9 | palaiokhora
# City not found. Skipping...
# Processing Record 46 of Set 9 | nioro
# Processing Record 47 of Set 9 | ust-tsilma
# Processing Record 48 of Set 9 | port hedland
# Processing Record 49 of Set 9 | lindsay
# Processing Record 50 of Set 9 | guanica
# Processing Record 1 of Set 10 | eureka
# Processing Record 2 of Set 10 | banepa
# Processing Record 3 of Set 10 | shahreza
# Processing Record 4 of Set 10 | sohag
# Processing Record 5 of Set 10 | lengshuijiang
# Processing Record 6 of Set 10 | flinders
# Processing Record 7 of Set 10 | basco
# Processing Record 8 of Set 10 | marzuq
# Processing Record 9 of Set 10 | lompoc
# Processing Record 10 of Set 10 | ilulissat
# Processing Record 11 of Set 10 | namibe
# Processing Record 12 of Set 10 | north bend
# Processing Record 13 of Set 10 | tutoia
# Processing Record 14 of Set 10 | gunzburg
# Processing Record 15 of Set 10 | den helder
# Processing Record 16 of Set 10 | dubbo
# Processing Record 17 of Set 10 | severo-yeniseyskiy
# Processing Record 18 of Set 10 | komsomolskiy
# Processing Record 19 of Set 10 | kununurra
# Processing Record 20 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 21 of Set 10 | morwa
# Processing Record 22 of Set 10 | lazaro cardenas
# Processing Record 23 of Set 10 | yuyao
# Processing Record 24 of Set 10 | merauke
# Processing Record 25 of Set 10 | pochutla
# Processing Record 26 of Set 10 | ntungamo
# Processing Record 27 of Set 10 | beira
# Processing Record 28 of Set 10 | fort-shevchenko
# Processing Record 29 of Set 10 | victor harbor
# Processing Record 30 of Set 10 | joshimath
# Processing Record 31 of Set 10 | vao
# Processing Record 32 of Set 10 | fairbanks
# Processing Record 33 of Set 10 | kemijarvi
# Processing Record 34 of Set 10 | cognac
# Processing Record 35 of Set 10 | krasnoselkup
# Processing Record 36 of Set 10 | sijunjung
# Processing Record 37 of Set 10 | okha
# Processing Record 38 of Set 10 | rumoi
# Processing Record 39 of Set 10 | buchanan
# Processing Record 40 of Set 10 | saint-joseph
# Processing Record 41 of Set 10 | karratha
# Processing Record 42 of Set 10 | kalomo
# City not found. Skipping...
# Processing Record 43 of Set 10 | ahmadpur
# Processing Record 44 of Set 10 | jequie
# Processing Record 45 of Set 10 | songea
# Processing Record 46 of Set 10 | sandpoint
# Processing Record 47 of Set 10 | sao geraldo do araguaia
# Processing Record 48 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 10 | barreirinhas
# Processing Record 50 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 11 | sinnamary
# Processing Record 2 of Set 11 | dauphin
# Processing Record 3 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 4 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 11 | guozhen
# Processing Record 6 of Set 11 | todos santos
# Processing Record 7 of Set 11 | faya
# Processing Record 8 of Set 11 | heihe
# Processing Record 9 of Set 11 | lumphat
# Processing Record 10 of Set 11 | terrace bay
# Processing Record 11 of Set 11 | bac lieu
# Processing Record 12 of Set 11 | biltine
# Processing Record 13 of Set 11 | santa isabel do rio negro
# Processing Record 14 of Set 11 | senlis
# Processing Record 15 of Set 11 | xiaoshi
# Processing Record 16 of Set 11 | muros
# Processing Record 17 of Set 11 | quimper
# Processing Record 18 of Set 11 | darhan
# Processing Record 19 of Set 11 | eyl
# Processing Record 20 of Set 11 | kieta
# Processing Record 21 of Set 11 | lityn
# Processing Record 22 of Set 11 | kibondo
# Processing Record 23 of Set 11 | port augusta
# Processing Record 24 of Set 11 | evanston
# Processing Record 25 of Set 11 | wick
# Processing Record 26 of Set 11 | sakaiminato
# Processing Record 27 of Set 11 | boffa
# Processing Record 28 of Set 11 | dakar
# Processing Record 29 of Set 11 | mbalmayo
# Processing Record 30 of Set 11 | srednekolymsk
# Processing Record 31 of Set 11 | indian harbour beach
# Processing Record 32 of Set 11 | tiarei
# Processing Record 33 of Set 11 | gillette
# Processing Record 34 of Set 11 | mezhdurechensk
# Processing Record 35 of Set 11 | mahinog
# Processing Record 36 of Set 11 | togur
# Processing Record 37 of Set 11 | traverse city
# Processing Record 38 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 11 | birjand
# Processing Record 40 of Set 11 | pavilosta
# Processing Record 41 of Set 11 | senno
# Processing Record 42 of Set 11 | eenhana
# Processing Record 43 of Set 11 | loudi
# Processing Record 44 of Set 11 | provideniya
# Processing Record 45 of Set 11 | kiyasovo
# Processing Record 46 of Set 11 | sorkjosen
# Processing Record 47 of Set 11 | dudinka
# Processing Record 48 of Set 11 | hualmay
# Processing Record 49 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 11 | barbacena
# Processing Record 1 of Set 12 | dabhoi
# Processing Record 2 of Set 12 | tucuma
# Processing Record 3 of Set 12 | borba
# Processing Record 4 of Set 12 | carndonagh
# Processing Record 5 of Set 12 | sapele
# Processing Record 6 of Set 12 | tiznit
# Processing Record 7 of Set 12 | williamsport
# Processing Record 8 of Set 12 | fare
# Processing Record 9 of Set 12 | hiranagar
# Processing Record 10 of Set 12 | hengyang
# Processing Record 11 of Set 12 | avanigadda
# Processing Record 12 of Set 12 | port macquarie
# Processing Record 13 of Set 12 | neepawa
# Processing Record 14 of Set 12 | auki
# Processing Record 15 of Set 12 | shimanovsk
# Processing Record 16 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 17 of Set 12 | lakes entrance
# Processing Record 18 of Set 12 | grand gaube
# Processing Record 19 of Set 12 | caraz
# Processing Record 20 of Set 12 | frontera
# Processing Record 21 of Set 12 | golden gate
# Processing Record 22 of Set 12 | upata
# Processing Record 23 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 12 | tura
# Processing Record 25 of Set 12 | bud
# Processing Record 26 of Set 12 | labuhan
# Processing Record 27 of Set 12 | selma
# Processing Record 28 of Set 12 | tadine
# Processing Record 29 of Set 12 | teguldet
# Processing Record 30 of Set 12 | fianarantsoa
# Processing Record 31 of Set 12 | beloha
# Processing Record 32 of Set 12 | wajima
# Processing Record 33 of Set 12 | west fargo
# Processing Record 34 of Set 12 | sarkand
# Processing Record 35 of Set 12 | antalaha
# Processing Record 36 of Set 12 | gorontalo
# Processing Record 37 of Set 12 | oistins
# Processing Record 38 of Set 12 | dipkarpaz
# City not found. Skipping...
# Processing Record 39 of Set 12 | macusani
# Processing Record 40 of Set 12 | sibolga
# Processing Record 41 of Set 12 | kvasice
# Processing Record 42 of Set 12 | south venice
# Processing Record 43 of Set 12 | omsukchan
# Processing Record 44 of Set 12 | atar
# Processing Record 45 of Set 12 | the valley
# Processing Record 46 of Set 12 | olgod
# Processing Record 47 of Set 12 | ugoofaaru
# Processing Record 48 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 49 of Set 12 | natchitoches
# Processing Record 50 of Set 12 | jalu
# Processing Record 1 of Set 13 | gimli
# Processing Record 2 of Set 13 | kavieng
# Processing Record 3 of Set 13 | syracuse
# Processing Record 4 of Set 13 | barranca
# Processing Record 5 of Set 13 | lumeje
# Processing Record 6 of Set 13 | datong
# Processing Record 7 of Set 13 | pontian kecil
# Processing Record 8 of Set 13 | dwarka
# Processing Record 9 of Set 13 | ekpoma
# Processing Record 10 of Set 13 | palmer
# Processing Record 11 of Set 13 | jojoima
# Processing Record 12 of Set 13 | nicoya
# Processing Record 13 of Set 13 | coquimbo
# Processing Record 14 of Set 13 | galway
# Processing Record 15 of Set 13 | aklavik
# Processing Record 16 of Set 13 | elliot lake
# Processing Record 17 of Set 13 | ust-barguzin
# Processing Record 18 of Set 13 | tacuati
# Processing Record 19 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 13 | alugan
# Processing Record 21 of Set 13 | bima
# Processing Record 22 of Set 13 | guadalajara
# Processing Record 23 of Set 13 | salinopolis
# Processing Record 24 of Set 13 | tilichiki
# Processing Record 25 of Set 13 | anloga
# Processing Record 26 of Set 13 | nanortalik
# Processing Record 27 of Set 13 | luan
# Processing Record 28 of Set 13 | sao gabriel da cachoeira
# Processing Record 29 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 30 of Set 13 | port said
# Processing Record 31 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 32 of Set 13 | roald
# Processing Record 33 of Set 13 | lensk
# Processing Record 34 of Set 13 | svetlogorsk
# Processing Record 35 of Set 13 | santa isabel
# Processing Record 36 of Set 13 | kavaratti
# Processing Record 37 of Set 13 | suntar
# Processing Record 38 of Set 13 | sola
# Processing Record 39 of Set 13 | katangli
# Processing Record 40 of Set 13 | sandwick
# Processing Record 41 of Set 13 | kamenka
# Processing Record 42 of Set 13 | yantzaza
# Processing Record 43 of Set 13 | tselinnoye
# Processing Record 44 of Set 13 | mersing
# Processing Record 45 of Set 13 | coolum beach
# Processing Record 46 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 47 of Set 13 | narok
# Processing Record 48 of Set 13 | montepuez
# Processing Record 49 of Set 13 | xai-xai
# Processing Record 50 of Set 13 | acarau
# Processing Record 1 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 14 | yumen
# Processing Record 3 of Set 14 | katherine
# Processing Record 4 of Set 14 | enshi
# Processing Record 5 of Set 14 | fortuna foothills
# Processing Record 6 of Set 14 | diffa
# Processing Record 7 of Set 14 | puerto leguizamo
# Processing Record 8 of Set 14 | yeppoon
# Processing Record 9 of Set 14 | safakulevo
# Processing Record 10 of Set 14 | maningrida
# Processing Record 11 of Set 14 | aureliana
# Processing Record 12 of Set 14 | alenquer
# Processing Record 13 of Set 14 | bathsheba
# Processing Record 14 of Set 14 | gramado
# Processing Record 15 of Set 14 | xining
# Processing Record 16 of Set 14 | baracoa
# Processing Record 17 of Set 14 | tazovskiy
# Processing Record 18 of Set 14 | xiaolingwei
# Processing Record 19 of Set 14 | seoul
# Processing Record 20 of Set 14 | moose factory
# Processing Record 21 of Set 14 | sulangan
# Processing Record 22 of Set 14 | tongliao
# Processing Record 23 of Set 14 | rocha
# Processing Record 24 of Set 14 | dongsheng
# Processing Record 25 of Set 14 | chimbote
# Processing Record 26 of Set 14 | shenjiamen
# Processing Record 27 of Set 14 | huilong
# Processing Record 28 of Set 14 | tingi
# Processing Record 29 of Set 14 | hermosillo
# Processing Record 30 of Set 14 | mahanoro
# Processing Record 31 of Set 14 | sinegorsk
# Processing Record 32 of Set 14 | nisia floresta
# Processing Record 33 of Set 14 | ailigandi
# Processing Record 34 of Set 14 | vega de alatorre
# Processing Record 35 of Set 14 | kaa-khem
# Processing Record 36 of Set 14 | richards bay
# Processing Record 37 of Set 14 | sherpur
# Processing Record 38 of Set 14 | beaverlodge
# Processing Record 39 of Set 14 | nome
# Processing Record 40 of Set 14 | mizpe ramon
# City not found. Skipping...
# Processing Record 41 of Set 14 | tual
# Processing Record 42 of Set 14 | williams lake
# Processing Record 43 of Set 14 | champerico
# Processing Record 44 of Set 14 | pombos
# Processing Record 45 of Set 14 | luba
# Processing Record 46 of Set 14 | udachnyy
# Processing Record 47 of Set 14 | kudchi
# City not found. Skipping...
# Processing Record 48 of Set 14 | chapais
# Processing Record 49 of Set 14 | sonoita
# Processing Record 50 of Set 14 | palu
# Processing Record 1 of Set 15 | jiujiang
# Processing Record 2 of Set 15 | sibiti
# Processing Record 3 of Set 15 | raichur
# Processing Record 4 of Set 15 | medea
# Processing Record 5 of Set 15 | buraydah
# Processing Record 6 of Set 15 | statesville
# Processing Record 7 of Set 15 | fukue
# Processing Record 8 of Set 15 | baturaja
# Processing Record 9 of Set 15 | nanae
# Processing Record 10 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 15 | tupik
# Processing Record 12 of Set 15 | erenhot
# Processing Record 13 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 15 | birao
# Processing Record 15 of Set 15 | taoudenni
# Processing Record 16 of Set 15 | ithaki
# Processing Record 17 of Set 15 | nuuk
# Processing Record 18 of Set 15 | baijiantan
# Processing Record 19 of Set 15 | hirado
# Processing Record 20 of Set 15 | inhambane
# Processing Record 21 of Set 15 | mangrol
# Processing Record 22 of Set 15 | comodoro rivadavia
# Processing Record 23 of Set 15 | tongchuan
# Processing Record 24 of Set 15 | poso
# Processing Record 25 of Set 15 | evensk
# Processing Record 26 of Set 15 | shaunavon
# Processing Record 27 of Set 15 | gayny
# Processing Record 28 of Set 15 | keshan
# City not found. Skipping...
# Processing Record 29 of Set 15 | port-gentil
# Processing Record 30 of Set 15 | angoram
# Processing Record 31 of Set 15 | podgorica
# Processing Record 32 of Set 15 | fakel
# Processing Record 33 of Set 15 | moyale
# Processing Record 34 of Set 15 | samalaeulu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = city_data_df[["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0       Ushuaia      AR  2022-01-28 02:51:13 -54.8000  -68.3000     49.66
# 1     Caravelas      BR  2022-01-28 02:51:13 -17.7125  -39.2481     75.29
# 2          Atar      MR  2022-01-28 02:51:13  20.5169  -13.0499     63.97
# 3    Bredasdorp      ZA  2022-01-28 02:51:13 -34.5322   20.0403     60.12
# 4        Luanda      AO  2022-01-28 02:51:14  -8.8368   13.2343     77.07
# 5  Quatre Cocos      MU  2022-01-28 02:51:14 -20.2078   57.7625     77.09
# 6        Albany      US  2022-01-28 02:47:33  42.6001  -73.9662     26.80
# 7        Sampit      ID  2022-01-28 02:51:14  -2.5333  112.9500     84.88
# 8       Rikitea      PF  2022-01-28 02:47:55 -23.1203 -134.9692     78.62
# 9     Busselton      AU  2022-01-28 02:50:33 -33.6500  115.3333     80.04
#
#    Humidity  Cloudiness  Wind Speed
# 0        81          75        4.61
# 1        91           3        5.26
# 2        38         100        6.58
# 3        82           1        2.30
# 4        84         100        3.27
# 5        69           0        9.46
# 6        54         100        3.33
# 7        67         100        3.15
# 8        76          83       16.98
# 9        30           0        5.53

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
